# %% [markdown]
# MACHINE LEARNING INTRO
#
# ----refer----https://sparkbyexamples.com/machine-learning-for-beginners-tutorial/
# (use this link efficiently for whole ml)
#
# --refer--
# https://www.sas.com/en_gb/insights/articles/analytics/machine-learning-algorithms.html#:~:text=As%20new%20data%20is%20fed,-supervised%2C%algorithms.html#:~:text=As%20new%20data%20is%20fed,%2Dsupervised%2C%20unsupervised%20and%20reinforcement.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)
# https://youtu.be/OCwZyYH14uw?si=E0iuh3NLkp_X1FNP
#
#   [Classification vs Clustering: https://www.geeksforgeeks.org/ml-classification-vs-clustering/
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# https://www.javatpoint.com/semi-supervised-learning
#
# https://www.ibm.com/topics/unsupervised-learning
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ---refer-------https://machinelearningmastery.com/supervised-and-unsupervised-machine-learning-algorithms/#:~:text=It%20is%20called%20supervised%20learning,is%20corrected%20by%20the%20teacher.

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/02/introduction-to-reinforcement-learning-for-beginners/
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# What are the most common and popular machine learning algorithms?---https://www.sas.com/en_gb/insights/articles/analytics/machine-learning-algorithms.html#:~:text=As%20new%20data%20is%20fed,%2Dsupervised%2C%20unsupervised%20and%20reinforcement.
#
#
# Top 10 Machine Learning Algorithms And Its Use Cases:https://medium.com/@imaginorlabs/top-10-machine-learning-algorithms-and-its-use-cases-fc303daa2003

# %% [markdown]
# When to Use Linear Regression, Clustering, or Decision Trees
#
# https://dzone.com/articles/decision-trees-vs-clustering-algorithms-vs-linear
